# %%
# -*- coding: utf-8 -*-
"""과제4 딥러닝 4 Fashion MNIST

"""

import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD,Adam,Adagrad,RMSprop

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

g_org_model_acc = 0 # 기존 모델의 정확도를 저장할 변수

# fashion MNIST 읽어 와서 신경망에 입력할 형태로 변환
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train=x_train.astype(np.float32)/255.0
x_test=x_test.astype(np.float32)/255.0
y_train=tf.keras.utils.to_categorical(y_train,10)
y_test=tf.keras.utils.to_categorical(y_test,10)

# 모델을 설계해주는 함수(모델을 나타내는 객체 model을 반환)
def build_model():
    model=Sequential()
    model.add(Dense(512,activation='relu',input_shape=(784,)))
    model.add(Dense(512,activation='relu'))
    model.add(Dense(10,activation='softmax'))
    return model

# Adam 옵티마이저를 사용하는 모델
dmlp_adam=build_model()
dmlp_adam.compile(loss='categorical_crossentropy', optimizer=Adam(),
                  metrics=['accuracy'])
hist_adam=dmlp_adam.fit(x_train, y_train, batch_size=256, 
                        epochs=50, validation_data=(x_test,y_test), verbose=2)

# 기존 모델의 정확률을 출력
g_org_model_acc = dmlp_adam.evaluate(x_test,y_test,verbose=0)[1]*100 #지우지 마시오
print("기본 모델 정확률은", g_org_model_acc)


# 여기 함수를 수정하여 본인만의 새로운 모델을 만드시오
def proposed_model():
    model=Sequential()
    model.add(Dense(1024,activation='relu',input_shape=(784,)))
    model.add(Dense(512,activation='relu'))
    model.add(Dense(512,activation='relu'))   # 레이어를 더 추가하고 싶은 경우, 여기 주석처럼 이 자리에 라인을 추가하면 됨.
    model.add(Dense(512,activation='relu'))   # 레이어를 더 추가하고 싶은 경우, 여기 주석처럼 이 자리에 라인을 추가하면 됨.
    model.add(Dense(10,activation='softmax'))
    return model

# 본인만의 새로운 모델
my_model = proposed_model()
my_model.compile(loss='categorical_crossentropy', optimizer=Adam(),
                  metrics=['accuracy'])
                  
# [※주의] 변경하면 안되는 옵션 : epochs, batch_size, _train, _text
hist_adam=my_model.fit(x_train, y_train, batch_size=256, 
                        epochs=50, validation_data=(x_test,y_test), verbose=2)

# 내가 개선한 모델의 정확률을 기존과 비교하며 출력
print("Baseline vs. Mine", g_org_model_acc,
      my_model.evaluate(x_test,y_test,verbose=0)[1]*100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 235/235 - 9s - loss: 0.5079 - accuracy: 0.8213 - val_loss: 0.4320 - val_accuracy: 0.8414 - 9s/epoch - 38ms/step
# Epoch 2/50
# 235/235 - 5s - loss: 0.3621 - accuracy: 0.8683 - val_loss: 0.3764 - val_accuracy: 0.8641 - 5s/epoch - 22ms/step
# Epoch 3/50
# 235/235 - 5s - loss: 0.3170 - accuracy: 0.8835 - val_loss: 0.3437 - val_accuracy: 0.8786 - 5s/epoch - 22ms/step
# Epoch 4/50
# 235/235 - 5s - loss: 0.2941 - accuracy: 0.8905 - val_loss: 0.3614 - val_accuracy: 0.8674 - 5s/epoch - 21ms/step
# Epoch 5/50
# 235/235 - 5s - loss: 0.2752 - accuracy: 0.8985 - val_loss: 0.3500 - val_accuracy: 0.8730 - 5s/epoch - 22ms/step
# Epoch 6/50
# 235/235 - 5s - loss: 0.2592 - accuracy: 0.9031 - val_loss: 0.3247 - val_accuracy: 0.8848 - 5s/epoch - 21ms/step
# Epoch 7/50
# 235/235 - 5s - loss: 0.2469 - accuracy: 0.9084 - val_loss: 0.3355 - val_accuracy: 0.8832 - 5s/epoch - 22ms/step
# Epoch 8/50
# 235/235 - 5s - loss: 0.2338 - accuracy: 0.9118 - val_loss: 0.3194 - val_accuracy: 0.8904 - 5s/epoch - 22ms/step
# Epoch 9/50
# 235/235 - 5s - loss: 0.2259 - accuracy: 0.9148 - val_loss: 0.3213 - val_accuracy: 0.8864 - 5s/epoch - 22ms/step
# Epoch 10/50
# 235/235 - 5s - loss: 0.2135 - accuracy: 0.9200 - val_loss: 0.3150 - val_accuracy: 0.8860 - 5s/epoch - 21ms/step
# Epoch 11/50
# 235/235 - 5s - loss: 0.2039 - accuracy: 0.9240 - val_loss: 0.3327 - val_accuracy: 0.8888 - 5s/epoch - 21ms/step
# Epoch 12/50
# 235/235 - 5s - loss: 0.1955 - accuracy: 0.9264 - val_loss: 0.3322 - val_accuracy: 0.8885 - 5s/epoch - 21ms/step
# Epoch 13/50
# 235/235 - 5s - loss: 0.1898 - accuracy: 0.9283 - val_loss: 0.3205 - val_accuracy: 0.8899 - 5s/epoch - 22ms/step
# Epoch 14/50
# 235/235 - 5s - loss: 0.1779 - accuracy: 0.9326 - val_loss: 0.3191 - val_accuracy: 0.8951 - 5s/epoch - 21ms/step
# Epoch 15/50
# 235/235 - 5s - loss: 0.1746 - accuracy: 0.9334 - val_loss: 0.3177 - val_accuracy: 0.8925 - 5s/epoch - 21ms/step
# Epoch 16/50
# 235/235 - 5s - loss: 0.1615 - accuracy: 0.9384 - val_loss: 0.3327 - val_accuracy: 0.8937 - 5s/epoch - 21ms/step
# Epoch 17/50
# 235/235 - 5s - loss: 0.1599 - accuracy: 0.9389 - val_loss: 0.3465 - val_accuracy: 0.8919 - 5s/epoch - 22ms/step
# Epoch 18/50
# 235/235 - 5s - loss: 0.1548 - accuracy: 0.9410 - val_loss: 0.3708 - val_accuracy: 0.8887 - 5s/epoch - 22ms/step
# Epoch 19/50
# 235/235 - 5s - loss: 0.1449 - accuracy: 0.9452 - val_loss: 0.3553 - val_accuracy: 0.8868 - 5s/epoch - 21ms/step
# Epoch 20/50
# 235/235 - 5s - loss: 0.1392 - accuracy: 0.9466 - val_loss: 0.3518 - val_accuracy: 0.8986 - 5s/epoch - 22ms/step
# Epoch 21/50
# 235/235 - 5s - loss: 0.1382 - accuracy: 0.9469 - val_loss: 0.3724 - val_accuracy: 0.8902 - 5s/epoch - 23ms/step
# Epoch 22/50
# 235/235 - 7s - loss: 0.1350 - accuracy: 0.9490 - val_loss: 0.3689 - val_accuracy: 0.8892 - 7s/epoch - 28ms/step
# Epoch 23/50
# 235/235 - 5s - loss: 0.1267 - accuracy: 0.9517 - val_loss: 0.3632 - val_accuracy: 0.8980 - 5s/epoch - 22ms/step
# Epoch 24/50
# 235/235 - 5s - loss: 0.1182 - accuracy: 0.9560 - val_loss: 0.3704 - val_accuracy: 0.8988 - 5s/epoch - 21ms/step
# Epoch 25/50
# 235/235 - 5s - loss: 0.1182 - accuracy: 0.9545 - val_loss: 0.3953 - val_accuracy: 0.8962 - 5s/epoch - 21ms/step
# Epoch 26/50
# 235/235 - 5s - loss: 0.1122 - accuracy: 0.9567 - val_loss: 0.3847 - val_accuracy: 0.8968 - 5s/epoch - 21ms/step
# Epoch 27/50
# 235/235 - 5s - loss: 0.1074 - accuracy: 0.9592 - val_loss: 0.4259 - val_accuracy: 0.8853 - 5s/epoch - 21ms/step
# Epoch 28/50
# 235/235 - 5s - loss: 0.1022 - accuracy: 0.9611 - val_loss: 0.4096 - val_accuracy: 0.8914 - 5s/epoch - 21ms/step
# Epoch 29/50
# 235/235 - 5s - loss: 0.0987 - accuracy: 0.9622 - val_loss: 0.4227 - val_accuracy: 0.8936 - 5s/epoch - 21ms/step
# Epoch 30/50
# 235/235 - 5s - loss: 0.0966 - accuracy: 0.9638 - val_loss: 0.4120 - val_accuracy: 0.8941 - 5s/epoch - 21ms/step
# Epoch 31/50
# 235/235 - 5s - loss: 0.0921 - accuracy: 0.9646 - val_loss: 0.4071 - val_accuracy: 0.8946 - 5s/epoch - 21ms/step
# Epoch 32/50
# 235/235 - 5s - loss: 0.0902 - accuracy: 0.9652 - val_loss: 0.4121 - val_accuracy: 0.8929 - 5s/epoch - 22ms/step
# Epoch 33/50
# 235/235 - 5s - loss: 0.0818 - accuracy: 0.9686 - val_loss: 0.4508 - val_accuracy: 0.8885 - 5s/epoch - 21ms/step
# Epoch 34/50
# 235/235 - 5s - loss: 0.0805 - accuracy: 0.9687 - val_loss: 0.4546 - val_accuracy: 0.8940 - 5s/epoch - 21ms/step
# Epoch 35/50
# 235/235 - 5s - loss: 0.0756 - accuracy: 0.9708 - val_loss: 0.4981 - val_accuracy: 0.8926 - 5s/epoch - 22ms/step
# Epoch 36/50
# 235/235 - 5s - loss: 0.0792 - accuracy: 0.9698 - val_loss: 0.4689 - val_accuracy: 0.8982 - 5s/epoch - 22ms/step
# Epoch 37/50
# 235/235 - 5s - loss: 0.0757 - accuracy: 0.9716 - val_loss: 0.4879 - val_accuracy: 0.8966 - 5s/epoch - 22ms/step
# Epoch 38/50
# 235/235 - 5s - loss: 0.0680 - accuracy: 0.9741 - val_loss: 0.4629 - val_accuracy: 0.8915 - 5s/epoch - 21ms/step
# Epoch 39/50
# 235/235 - 5s - loss: 0.0679 - accuracy: 0.9746 - val_loss: 0.4797 - val_accuracy: 0.8978 - 5s/epoch - 21ms/step
# Epoch 40/50
# 235/235 - 5s - loss: 0.0643 - accuracy: 0.9760 - val_loss: 0.5205 - val_accuracy: 0.8945 - 5s/epoch - 21ms/step
# Epoch 41/50
# 235/235 - 5s - loss: 0.0687 - accuracy: 0.9738 - val_loss: 0.5107 - val_accuracy: 0.8865 - 5s/epoch - 21ms/step
# Epoch 42/50
# 235/235 - 5s - loss: 0.0630 - accuracy: 0.9766 - val_loss: 0.5137 - val_accuracy: 0.8952 - 5s/epoch - 21ms/step
# Epoch 43/50
# 235/235 - 5s - loss: 0.0611 - accuracy: 0.9768 - val_loss: 0.5051 - val_accuracy: 0.8960 - 5s/epoch - 21ms/step
# Epoch 44/50
# 235/235 - 5s - loss: 0.0598 - accuracy: 0.9774 - val_loss: 0.5271 - val_accuracy: 0.8904 - 5s/epoch - 21ms/step
# Epoch 45/50
# 235/235 - 5s - loss: 0.0669 - accuracy: 0.9757 - val_loss: 0.4902 - val_accuracy: 0.8972 - 5s/epoch - 21ms/step
# Epoch 46/50
# 235/235 - 5s - loss: 0.0516 - accuracy: 0.9815 - val_loss: 0.5321 - val_accuracy: 0.8934 - 5s/epoch - 21ms/step
# Epoch 47/50
# 235/235 - 5s - loss: 0.0511 - accuracy: 0.9808 - val_loss: 0.5439 - val_accuracy: 0.8948 - 5s/epoch - 21ms/step
# Epoch 48/50
# 235/235 - 5s - loss: 0.0472 - accuracy: 0.9823 - val_loss: 0.5453 - val_accuracy: 0.8932 - 5s/epoch - 21ms/step
# Epoch 49/50
# 235/235 - 5s - loss: 0.0453 - accuracy: 0.9831 - val_loss: 0.5744 - val_accuracy: 0.8980 - 5s/epoch - 21ms/step
# Epoch 50/50
# 235/235 - 5s - loss: 0.0443 - accuracy: 0.9832 - val_loss: 0.5823 - val_accuracy: 0.8907 - 5s/epoch - 21ms/step
# 기본 모델 정확률은 89.06999826431274
# Epoch 1/50
# 235/235 - 14s - loss: 0.5101 - accuracy: 0.8160 - val_loss: 0.4544 - val_accuracy: 0.8347 - 14s/epoch - 60ms/step
# Epoch 2/50
# 235/235 - 14s - loss: 0.3626 - accuracy: 0.8673 - val_loss: 0.3786 - val_accuracy: 0.8627 - 14s/epoch - 57ms/step
# Epoch 3/50
# 235/235 - 13s - loss: 0.3197 - accuracy: 0.8827 - val_loss: 0.3756 - val_accuracy: 0.8644 - 13s/epoch - 57ms/step
# Epoch 4/50
# 235/235 - 13s - loss: 0.2996 - accuracy: 0.8881 - val_loss: 0.3687 - val_accuracy: 0.8655 - 13s/epoch - 57ms/step
# Epoch 5/50
# 235/235 - 13s - loss: 0.2766 - accuracy: 0.8960 - val_loss: 0.3371 - val_accuracy: 0.8732 - 13s/epoch - 57ms/step
# Epoch 6/50
# 235/235 - 14s - loss: 0.2591 - accuracy: 0.9018 - val_loss: 0.3270 - val_accuracy: 0.8822 - 14s/epoch - 57ms/step
# Epoch 7/50
# 235/235 - 14s - loss: 0.2456 - accuracy: 0.9068 - val_loss: 0.3480 - val_accuracy: 0.8787 - 14s/epoch - 58ms/step
# Epoch 8/50
# 235/235 - 13s - loss: 0.2386 - accuracy: 0.9088 - val_loss: 0.3269 - val_accuracy: 0.8853 - 13s/epoch - 57ms/step
# Epoch 9/50
# 235/235 - 14s - loss: 0.2293 - accuracy: 0.9125 - val_loss: 0.3105 - val_accuracy: 0.8904 - 14s/epoch - 58ms/step
# Epoch 10/50
# 235/235 - 13s - loss: 0.2215 - accuracy: 0.9160 - val_loss: 0.3187 - val_accuracy: 0.8849 - 13s/epoch - 57ms/step
# Epoch 11/50
# 235/235 - 14s - loss: 0.2071 - accuracy: 0.9202 - val_loss: 0.3373 - val_accuracy: 0.8857 - 14s/epoch - 58ms/step
# Epoch 12/50
# 235/235 - 14s - loss: 0.1993 - accuracy: 0.9233 - val_loss: 0.3168 - val_accuracy: 0.8944 - 14s/epoch - 58ms/step
# Epoch 13/50
# 235/235 - 13s - loss: 0.1941 - accuracy: 0.9252 - val_loss: 0.3333 - val_accuracy: 0.8904 - 13s/epoch - 57ms/step
# Epoch 14/50
# 235/235 - 13s - loss: 0.1829 - accuracy: 0.9295 - val_loss: 0.3311 - val_accuracy: 0.8911 - 13s/epoch - 57ms/step
# Epoch 15/50
# 235/235 - 14s - loss: 0.1779 - accuracy: 0.9307 - val_loss: 0.3443 - val_accuracy: 0.8879 - 14s/epoch - 58ms/step
# Epoch 16/50
# 235/235 - 13s - loss: 0.1693 - accuracy: 0.9345 - val_loss: 0.3547 - val_accuracy: 0.8910 - 13s/epoch - 57ms/step
# Epoch 17/50
# 235/235 - 13s - loss: 0.1664 - accuracy: 0.9354 - val_loss: 0.3568 - val_accuracy: 0.8877 - 13s/epoch - 57ms/step
# Epoch 18/50
# 235/235 - 13s - loss: 0.1693 - accuracy: 0.9346 - val_loss: 0.3665 - val_accuracy: 0.8902 - 13s/epoch - 57ms/step
# Epoch 19/50
# 235/235 - 13s - loss: 0.1511 - accuracy: 0.9418 - val_loss: 0.3867 - val_accuracy: 0.8856 - 13s/epoch - 57ms/step
# Epoch 20/50
# 235/235 - 14s - loss: 0.1486 - accuracy: 0.9421 - val_loss: 0.3732 - val_accuracy: 0.8921 - 14s/epoch - 58ms/step
# Epoch 21/50
# 235/235 - 14s - loss: 0.1469 - accuracy: 0.9427 - val_loss: 0.3455 - val_accuracy: 0.8963 - 14s/epoch - 58ms/step
# Epoch 22/50
# 235/235 - 14s - loss: 0.1368 - accuracy: 0.9471 - val_loss: 0.4210 - val_accuracy: 0.8917 - 14s/epoch - 58ms/step
# Epoch 23/50
# 235/235 - 14s - loss: 0.1355 - accuracy: 0.9475 - val_loss: 0.3978 - val_accuracy: 0.8962 - 14s/epoch - 58ms/step
# Epoch 24/50
# 235/235 - 14s - loss: 0.1300 - accuracy: 0.9494 - val_loss: 0.3909 - val_accuracy: 0.8892 - 14s/epoch - 58ms/step
# Epoch 25/50
# 235/235 - 14s - loss: 0.1254 - accuracy: 0.9505 - val_loss: 0.3868 - val_accuracy: 0.8985 - 14s/epoch - 58ms/step
# Epoch 26/50
# 235/235 - 14s - loss: 0.1214 - accuracy: 0.9532 - val_loss: 0.4234 - val_accuracy: 0.8953 - 14s/epoch - 58ms/step
# Epoch 27/50
# 235/235 - 14s - loss: 0.1180 - accuracy: 0.9534 - val_loss: 0.3992 - val_accuracy: 0.8937 - 14s/epoch - 58ms/step
# Epoch 28/50
# 235/235 - 14s - loss: 0.1134 - accuracy: 0.9559 - val_loss: 0.4525 - val_accuracy: 0.8917 - 14s/epoch - 58ms/step
# Epoch 29/50
# 235/235 - 14s - loss: 0.1081 - accuracy: 0.9580 - val_loss: 0.4607 - val_accuracy: 0.8917 - 14s/epoch - 58ms/step
# Epoch 30/50
# 235/235 - 14s - loss: 0.1072 - accuracy: 0.9578 - val_loss: 0.4228 - val_accuracy: 0.8912 - 14s/epoch - 58ms/step
# Epoch 31/50
# 235/235 - 13s - loss: 0.1000 - accuracy: 0.9611 - val_loss: 0.4405 - val_accuracy: 0.8915 - 13s/epoch - 57ms/step
# Epoch 32/50
# 235/235 - 13s - loss: 0.1006 - accuracy: 0.9613 - val_loss: 0.4108 - val_accuracy: 0.8973 - 13s/epoch - 57ms/step
# Epoch 33/50
# 235/235 - 14s - loss: 0.0952 - accuracy: 0.9623 - val_loss: 0.4909 - val_accuracy: 0.8899 - 14s/epoch - 58ms/step
# Epoch 34/50
# 235/235 - 14s - loss: 0.0920 - accuracy: 0.9650 - val_loss: 0.4477 - val_accuracy: 0.8970 - 14s/epoch - 58ms/step
# Epoch 35/50
# 235/235 - 14s - loss: 0.0867 - accuracy: 0.9673 - val_loss: 0.4569 - val_accuracy: 0.8891 - 14s/epoch - 57ms/step
# Epoch 36/50
# 235/235 - 14s - loss: 0.0860 - accuracy: 0.9664 - val_loss: 0.4816 - val_accuracy: 0.8978 - 14s/epoch - 57ms/step
# Epoch 37/50
# 235/235 - 14s - loss: 0.0806 - accuracy: 0.9687 - val_loss: 0.5475 - val_accuracy: 0.8958 - 14s/epoch - 58ms/step
# Epoch 38/50
# 235/235 - 14s - loss: 0.0775 - accuracy: 0.9696 - val_loss: 0.4966 - val_accuracy: 0.8947 - 14s/epoch - 58ms/step
# Epoch 39/50
# 235/235 - 14s - loss: 0.0799 - accuracy: 0.9692 - val_loss: 0.4868 - val_accuracy: 0.8937 - 14s/epoch - 58ms/step
# Epoch 40/50
# 235/235 - 14s - loss: 0.0781 - accuracy: 0.9696 - val_loss: 0.5246 - val_accuracy: 0.8936 - 14s/epoch - 58ms/step
# Epoch 41/50
# 235/235 - 14s - loss: 0.0741 - accuracy: 0.9708 - val_loss: 0.5173 - val_accuracy: 0.8954 - 14s/epoch - 58ms/step
# Epoch 42/50
# 235/235 - 14s - loss: 0.0707 - accuracy: 0.9723 - val_loss: 0.5212 - val_accuracy: 0.8927 - 14s/epoch - 58ms/step
# Epoch 43/50
# 235/235 - 14s - loss: 0.0710 - accuracy: 0.9726 - val_loss: 0.5533 - val_accuracy: 0.8973 - 14s/epoch - 58ms/step
# Epoch 44/50
# 235/235 - 13s - loss: 0.0663 - accuracy: 0.9752 - val_loss: 0.5696 - val_accuracy: 0.8932 - 13s/epoch - 57ms/step
# Epoch 45/50
# 235/235 - 13s - loss: 0.0646 - accuracy: 0.9752 - val_loss: 0.5384 - val_accuracy: 0.8973 - 13s/epoch - 57ms/step
# Epoch 46/50
# 235/235 - 14s - loss: 0.0617 - accuracy: 0.9759 - val_loss: 0.5016 - val_accuracy: 0.8953 - 14s/epoch - 58ms/step
# Epoch 47/50
# 235/235 - 14s - loss: 0.0614 - accuracy: 0.9773 - val_loss: 0.5788 - val_accuracy: 0.8932 - 14s/epoch - 58ms/step
# Epoch 48/50
# 235/235 - 13s - loss: 0.0585 - accuracy: 0.9777 - val_loss: 0.5780 - val_accuracy: 0.8984 - 13s/epoch - 57ms/step
# Epoch 49/50
# 235/235 - 14s - loss: 0.0584 - accuracy: 0.9782 - val_loss: 0.5617 - val_accuracy: 0.8960 - 14s/epoch - 57ms/step
# Epoch 50/50
# 235/235 - 13s - loss: 0.0554 - accuracy: 0.9782 - val_loss: 0.5891 - val_accuracy: 0.8943 - 13s/epoch - 57ms/step
# Baseline vs. Mine 89.06999826431274 89.42999839782715

# %%
import sys
print('python version : '+sys.version)
import numpy as np
import tensorflow as tf
print('numpy version : ' + np.__version__)
print('tensorflow version : ' + tf.__version__)
# Out:
# python version : 3.7.13 (default, Mar 16 2022, 17:37:17)
# [GCC 7.5.0]
# numpy version : 1.21.5
# tensorflow version : 2.8.0
